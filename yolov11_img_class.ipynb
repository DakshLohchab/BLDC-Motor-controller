# %% [markdown]
# <a href="https://colab.research.google.com/github/DakshLohchab/yollov11/blob/main/yolov11_img_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip /content/Fowl-pox.v1i.folder.zip
# Out:
# Archive:  /content/Fowl-pox.v1i.folder.zip
#    creating: Fowl-pox.v1i.folder/
#    creating: Fowl-pox.v1i.folder/train/
#    creating: Fowl-pox.v1i.folder/train/fowlpox/
#   inflating: Fowl-pox.v1i.folder/train/fowlpox/0_jpg.rf.48e45e4d0e5d50e0abf049c4b9c2ba1f.jpg
#   inflating: Fowl-pox.v1i.folder/train/fowlpox/0_jpg.rf.6823ba9bfab724e861dd8854b5fa68d2.jpg
#   inflating: Fowl-pox.v1i.folder/train/fowlpox/0_jpg.rf.ad5db090918734f8fbab976fed083f41.jpg
#   inflating: Fowl-pox.v1i.folder/train/fowlpox/100_jpg.rf.097a7a6dd28766a7ecd4516f288184f9.jpg
#   inflating: Fowl-pox.v1i.folder/train/fowlpox/100_jpg.rf.5fa2b00212f19427d49b1c11b3977d14.jpg
#   inflating: Fowl-pox.v1i.folder/train/fowlpox/100_jpg.rf.67518b19a3c5cc0b348b9cfe5fe7b493.jpg
#   inflating: Fowl-pox.v1i.folder/train/fowlpox/102_jpg.rf.0c44fc62a7451da3e213269c47280c51.jpg
#   inflating: Fowl-pox.v1i.folder/train/fowlpox/102_jpg.rf.7a1e6a1ab2003aeb8c5798fc4adc9309.jpg
# ...

# %% [markdown]
# **Training the model**

# %%
from ultralytics import YOLO

# loading the model
model = YOLO('yolo11n-cls.pt')

# train the model
results = model.train(data='/content/Fowl-pox.v1i.folder',epochs=20,imgsz=640)
# Out:
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 114MB/s]
# Ultralytics 8.3.168 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# **INFERENCE **

# %%
from IPython.display import Image

# %%
Image('/content/runs/classify/train/results.png',width=600)

# %%
model1 = YOLO('/content/runs/classify/train/weights/best.pt')

results = model1('/content/45_jpg.rf.f932e95b32cb1384263edb4ff29c4a5a.jpg')
results[0].show()
# Out:
# image 1/1 /content/45_jpg.rf.f932e95b32cb1384263edb4ff29c4a5a.jpg: 640x640 fowlpox 1.00, 4.6ms
# Speed: 17.8ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=224x224>
